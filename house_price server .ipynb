# %% [markdown]
# # # Search for all experiments

# %%
import  os
# Set the MLflow tracking URI environment variable to a local file path
os.environ["MLFLOW_TRACKING_URI"]='file:///Users/ponna/OneDrive/Desktop/dss'

# %%
import mlflow
# Search for all runs across all experiments
all_runs=mlflow.search_runs(search_all_experiments=True)
print(all_runs)
# Out:
#                               run_id       experiment_id    status  \
# 0   42326d88ee0d4f3da18c23aa67871efc  440793668394542207  FINISHED
# 1   3d4a2e6648c949888725b8b279d29ef6  678669909162272662  FINISHED
# 2   d1d2c10fa5bc470f8b2e10f5fe5b4165  678669909162272662  FINISHED
# 3   073e9102d3d1458382daa2c5185d042c  450307008082722861  FINISHED
# 4   cab2730d77064e1fb988070b23672eae  450307008082722861  FINISHED
# 5   8eb94c6ecba54c9599044a8e8d2bf865  678669909162272662  FINISHED
# 6   b1a81182cde445f6a525b7d868faf14d  678669909162272662  FINISHED
# 7   6c99664881624a959feb09802a8fa7ed  367232359215941870  FINISHED
# 8   db0e5a642e184a3dacbcb51672e73534  367232359215941870    FAILED
# 9   1204258d72de4f4b82b2d5e368d37dac  367232359215941870    FAILED
# 10  7cccf56ad8ff439caabb240c2e635e5c  367232359215941870    FAILED
#
#                                          artifact_uri  \
# 0   file:///C:/Users/ponna/OneDrive/Desktop/dss/44...
# ...

# %%
# !mlflow models serve -p 8164 -m runs:/42326d88ee0d4f3da18c23aa67871efc/random-forest-model --no-conda
